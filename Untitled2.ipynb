# %%
#PUNTO 12

# cantidad de palabras que va a pedir la lista
numero = 2
if numero < 1:
        print("¡Dura la situacion!")
else:
        # agregar las palabras a la lista
        lista = []
        for i in range(numero):
            print('Digite la palabra #', str(i + 1) + ": ", end="")
            palabra = input()
            lista += [palabra]
        listaord=sorted(lista) #crear una lista con las palabras ya ordenada

#imprimir cada elemento de la lista, donde listaord[0]esta primero en el 
#diccionario que listaord[1]         
print(listaord[0], 'esta primero en el diccionario que', listaord[1])

# %%
#PUNTO 16
import sys

List= eval(input('Introduzca una lista de números ordenada de forma ascendente'))

contador=0
       
for i in range(0,len(List)-1):     #Se evaluarán todos los índices, siendo
    if List[i]<=List[(i+1)]: #que el siguiente sea igual o mayor
        contador=contador #de lo contrario el cont dejará de valer cero
    else:                               
        contador=+1
        
if contador!=0:
    
    sys.exit('la lista no está ordenada de forma ascendente')
        


Nu= int(input('Introduzca un número'))

for i in range(0,len(List)):
    if Nu>=List[-1]:    #Si el último dígito de la lista es menor que
#que Nu se adicionará el Nu a la lista y se romperá el código. De lo contrario,
        List.append(Nu)  #itera cada índice hasta que se encuentre un num menor
                               
                               
        List.append(Nu)          
        break
    
    if Nu>List[i]:   #cumpliéndose esto, se insertará el N en la
        i+=1                    #posición i que se estaba evaluando
    
    if Nu<=List[i]:
        List.insert(i,Nu)
        break

print(List)

# %%
#PUNTO 18

# Asegurar que cumpla la definicion de matriz.
    
while True:
    try   :
        Matriz = eval(input('Ingrese la matriz cuadrada: '))
        
        # Comprueba que el elemento ingresado sea una lista
        if type(Matriz) is list :
            
            # Revisara cada elemento de la matriz o "Fila" y se cersioriara
            # de que cada uno sea tambien una fila.
            for Fila in Matriz:
                if type(Fila) is list:
                    
                    # Revisara cada elemento o "entrada" de cada fila
                    # y asegurara que sea un entero.
                    
                    for Entrada in Fila:
                        # Si no es un entero lanzara error.
                        if type(Entrada) is not int: raise Exception
            # En caso de que alguna fila no sea una lista lanzara un error
                else: raise Exception
        # En caso de que el elemento ingresado no se una lista
        # lanza un error.
        else: raise Exception
    
        # Toma la primera fila de la matriz como referencia, y se asegura 
        # de que todas las fila tengan la misma longitud que esta, en caso
        # contrario lanza error.
        for Fila in Matriz:
            if len(Fila) != len(Matriz[0]) : raise Exception
        
        # Si todo lo anterior sucede sin errores interrumpe el ciclo while.
        break
    
    except Exception:
        print('Alguno de los elementos de la matriz no cumple con \
la definicion de matriz. Revise su matriz e intentelo de nuevo.')
    
 
    
x=-1 #contador para que que indice de la fila aumente en 1, para conservar
#patron tirangular

for i in range(0,len(Matriz)): #Se creará un ciclo for para cambiar los índices
#debajo de la diagonal por ceros
    x+=1                                #i = columnas
    for j in range(1+x,len(Matriz)):         #j = filas
        Matriz[j][i]=0
print('La matriz triangular superior es:',Matriz)

# %%
#PUNTO 19
while True: # asegura que se digite una lista
    try: 
        Lista1=eval(input('Ingrese una lista: ')) 
        if type(Lista1) == list:
            for i in Lista1:
                if type(i) == int:
                    continue
                else: raise Exception
            break
        else: raise Exception
    except Exception: print('El elemento ingresado debe ser una lista de\
 numeros enteros')
    
    
Lista1.append(0)
l= 0
Lista2 = [[]]
for i in range(0,len(Lista1)-1): #Evalúa el índice i con el siguiente comparando
#si el #segundo es mayor que el primero, sucediendo esto, se agregará a una 
#sublista
    if Lista1[i] <= Lista1[i+1]:
        Lista2[l].append(Lista1[i])
    else:
        Lista2[l].append(Lista1[i])
        l+= 1
        Lista2.append([]) #Cuando se llegue a un número que no cumpla esta 
#condición, se agrega una nueva sublista vacía y el programa seguirá iterando
#buscando el mismo patrón 
       
Lista3=[]

for i in Lista2:
    Lista3.append(len(i))
    

a= max(Lista3)#Se halla el máximo elemento de la lista Lista3 y será impreso
while a in Lista3: #si encuentra dos elementos con la misma longitud,
#se imprimirán ambos por medio
#de pop, imprimiendo el primero, eliminándolo y dándole paso al segundo
#para ser evaluado con el comando "max" y ser impreso posteriormente

    
   

    
    print(Lista2.pop(Lista3.index(max(Lista3))), ' sublista ordenada\
 ascendentemente más larga')
    
    Lista3.pop(Lista3.index(max(Lista3)))

# %%
#PUNTO 20
def Leer_matriz():
    '''
    lee una matriz que contenga listas,que sus elementos sean enteros y que
    sea de cualquier longitud
    '''
    while True:
        try:
            M= eval(input('Diigite una matriz: '))
            if type(M) is list:
                for fila in M:
                    if type(fila) is list:
                        for entrada in fila:
                            if type(entrada) is not int:
                                raise Exception
                    else:
                        raise Exception
            else:
                raise Exception
            
            for Fila in M:
                if len(Fila) != len(M[0]) :
                    raise Exception
            break     
        except:
            print('Debe ser una matriz de numeros enteros con todas sus filas\
 iguales.')
            
    return M
